# %%
from IPython.display import Image

# %%
Image(filename="test.jpg")

# %%
from IPython.display import YouTubeVideo

# %%
# URL: https://www.youtube.com/watch?v=O9IlAWooibw
YouTubeVideo("O9IlAWooibw")

# %%
# %%capture output
# %ls

# %%
output.stdout
# Out:
# u'05train.txt                     python-q-table-learning.ipynb\r\nChapter 2.ipynb                 python-tf-contextual-bandits.ipynb\r\n\x1b\x1bMNIST_data\x1b/                     python-tf-lstm.ipynb\r\nderby.log                       python-tf-multi-armed-bandits.ipynb\r\nexample.txt                     python-tf-q-network-learning.ipynb\r\nfull_user.avsc                  python-tf-snl.ipynb\r\ninput_data.py                   python-tf-word2vec.ipynb\r\ninput_data.pyc                  python-word2vec.ipynb\r\njulia-pycall.ipynb              r-dataframe.ipynb\r\njulia-task.ipynb                scala-spark.ipynb\r\nk-means.ipynb                   shipper_tcp.ipynb\r\nkv1.txt                         spark-repository-error.ipynb\r\nmatplotlib.ipynb                \x1bspark-warehouse\x1b/\r\n\x1bmetastore_db\x1b/                   spark_and_tensorflow.ipynb\r\npeople.json                     \x1btensorflow-lstm-regression-master\x1b/\r\npeople.txt                      test.jpg\r\npytho
# ...

# %%
import pyscreenshot as ImageGrab

im=ImageGrab.grab()
im.show()
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-15-4998678d2f6a> in <module>()
# ----> 1 import pyscreenshot as ImageGrab
#       2
#       3 im=ImageGrab.grab()
#       4 im.show()
#
# ImportError: No module named pyscreenshot
