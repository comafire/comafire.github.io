# %%
import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename +
                        '. Can you get to it with a browser?')
    return filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data


words = read_data(filename)
print('Data size', len(words))
print(words[0], words[1])
# Out:
# Data size 17005207
# anarchism originated

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

# vocabulary_size = 10


def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0


# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels


batch, labels = generate_batch(batch_size=8, num_skips=4, skip_window=2)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i],
          reverse_dictionary[labels[i, 0]])
# Out:
# 12 as -> [3081] originated
# 12 as -> [5239] anarchism
# 12 as -> [6] a
# 12 as -> [195] term
# 6 a -> [3081] originated
# 6 a -> [12] as
# 6 a -> [2] of
# 6 a -> [195] term

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 2  # How many words to consider left and right.
num_skips = 4  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal(
                [vocabulary_size, embedding_size],
                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                    skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  274.510894775
# Nearest to he: coburg, hart, sio, homophones, mvs, deforestation, moshiach, thuringia,
# Nearest to if: reykjav, hildebrand, nne, pectoral, wankel, bird, monocots, biochemical,
# Nearest to can: guardian, effectively, edmonds, buildings, lorenz, syed, endpoint, micheal,
# Nearest to at: insertions, titian, consistently, inquiries, therapeutic, obstetrics, duodenum, evacuate,
# Nearest to while: seton, jannaeus, folk, setup, corfu, pilot, personnel, tenuous,
# Nearest to i: encompassed, alchemical, fresh, strafford, skip, prokaryotic, brett, complained,
# Nearest to and: aung, errol, rosenzweig, agreeable, anglicized, aspires, erasure, fetish,
# Nearest to often: grierson, pretending, airlift, brink, flyer, alsace, gt, invoke,
# Nearest to had: caltech, kalamazoo, enabling, hepatitis, mbeki, cranial, duodecimal, discontinue,
# Nearest to when: solidifies, lag, opiate, clippers, reidel, museu, etsi, royce,
# Nearest to nine: moriarty, escudo, magi, emoticon, problem, aaron, crooked, parisians,
# Nearest to was: wiesel, hay, loxodonta, governed, teresa, hagen, contradicted, prosciutto,
# Nearest to would: falwell, abrogation, lizzie, confederates, arthropod, conceptualized, minamoto, believed,
# Nearest to most: lifton, msn, pieter, microseconds, fundamentally, totalled, quechua, usc,
# Nearest to by: iaea, roles, mccullough, racers, violation, sumatran, unable, goes,
# Nearest to s: zimmermann, arin, clg, vikrant, loos, pickwick, lust, hydrogens,
# Average loss at step  2000 :  114.227240572
# Average loss at step  4000 :  53.1751498272
# Average loss at step  6000 :  34.0118407128
# Average loss at step  8000 :  24.6224656326
# Average loss at step  10000 :  17.9625728507
# Nearest to he: and, potato, schott, combustion, pavia, greene, crow, aq,
# Nearest to if: railhead, reykjav, combustion, coptic, rugby, system, sketching, cm,
# Nearest to can: effectively, buildings, lorenz, nunavut, straightforwardly, a, newsgroup, ba,
# Nearest to at: therapeutic, psychedelic, of, sketching, goals, consistently, passer, pseudocode,
# Nearest to while: pilot, record, folk, global, to, ba, recognition, latvia,
# Nearest to i: alchemical, inscription, saul, down, nunavut, indemnity, aq, angered,
# Nearest to and: in, gland, of, to, potato, by, the, UNK,
# Nearest to often: gland, basins, foothills, woman, pseudocode, retains, courtesy, helped,
# Nearest to had: diatoms, enabling, psychedelic, junctions, chloroplasts, argued, was, leakey,
# Nearest to when: badge, zero, aq, yards, immigration, declines, isomers, and,
# Nearest to nine: zero, sketching, gland, one, combustion, potato, alps, basins,
# Nearest to was: is, gland, and, combustion, a, verse, railhead, has,
# Nearest to would: lens, confederates, ivb, agave, past, believed, only, energized,
# Nearest to most: zar, cushitic, rom, isabella, amphibians, municipalities, UNK, given,
# Nearest to by: and, to, gland, in, UNK, combustion, coptic, verse,
# Nearest to s: UNK, a, gland, and, of, combustion, one, the,
# Average loss at step  12000 :  16.073202364
# Average loss at step  14000 :  12.4573043139
# Average loss at step  16000 :  11.0544155564
# Average loss at step  18000 :  10.4166064487
# Average loss at step  20000 :  8.92321001458
# Nearest to he: and, it, that, rotate, UNK, four, phi, mathbf,
# Nearest to if: microscopy, reykjav, intercourse, railhead, is, monocots, preferential, rugby,
# Nearest to can: psi, konya, hers, lorenz, or, is, nunavut, effectively,
# Nearest to at: in, therapeutic, psychedelic, by, phi, two, of, and,
# Nearest to while: and, sx, to, phi, unarable, pilot, coke, folk,
# Nearest to i: alchemical, saul, inscription, indemnity, kramer, nunavut, fresh, and,
# Nearest to and: UNK, in, phi, with, by, of, s, or,
# Nearest to often: dddddd, basins, gland, gt, or, foothills, francium, helped,
# Nearest to had: was, and, are, mathbf, by, enabling, have, markov,
# Nearest to when: percussion, and, phi, gb, biscuit, coke, zero, with,
# Nearest to nine: eight, six, zero, five, four, three, two, one,
# Nearest to was: is, had, are, UNK, markov, and, konya, phi,
# Nearest to would: lens, coke, konya, ivb, inclusions, confederates, only, to,
# Nearest to most: zar, cushitic, dddddd, isabella, manufacture, amphibians, rom, municipalities,
# Nearest to by: and, with, in, UNK, from, to, for, gland,
# Nearest to s: and, the, UNK, in, of, coke, phi, gland,
# Average loss at step  22000 :  8.40062344098
# Average loss at step  24000 :  7.77585129523
# Average loss at step  26000 :  7.59058645368
# Average loss at step  28000 :  7.23986589265
# Average loss at step  30000 :  6.95320208383
# Nearest to he: it, that, dasyprocta, agouti, they, phi, rotate, and,
# Nearest to if: microscopy, peptidoglycan, intercourse, that, railhead, preferential, cardiff, reykjav,
# Nearest to can: psi, konya, or, hers, lorenz, nunavut, and, would,
# Nearest to at: of, operatorname, in, epistles, dasyprocta, phi, therapeutic, agouti,
# Nearest to while: and, sx, to, circ, operatorname, phi, hbox, unarable,
# Nearest to i: operatorname, saul, alchemical, lammas, nunnery, agouti, indemnity, inscription,
# Nearest to and: or, dasyprocta, operatorname, UNK, hbox, phi, agouti, with,
# Nearest to often: operatorname, dddddd, basins, for, gt, gland, dasyprocta, grierson,
# Nearest to had: was, have, by, epistles, has, are, is, mathbf,
# Nearest to when: and, but, dasyprocta, in, percussion, with, phi, gb,
# Nearest to nine: eight, six, five, seven, two, zero, one, four,
# Nearest to was: is, had, dasyprocta, are, hbox, operatorname, konya, circ,
# Nearest to would: lens, to, ivb, konya, coke, agouti, only, inclusions,
# Nearest to most: dasyprocta, zar, operatorname, hbox, convex, dddddd, isabella, municipalities,
# Nearest to by: with, and, from, operatorname, dasyprocta, as, for, agouti,
# Nearest to s: and, operatorname, dasyprocta, epistles, hbox, gland, coke, his,
# Average loss at step  32000 :  6.69715378499
# Average loss at step  34000 :  6.2727703501
# Average loss at step  36000 :  6.18181970537
# Average loss at step  38000 :  6.39108663809
# Average loss at step  40000 :  6.14121651304
# Nearest to he: it, by, they, dasyprocta, that, who, albuquerque, which,
# Nearest to if: microscopy, is, that, peptidoglycan, which, and, cardiff, preferential,
# Nearest to can: psi, would, konya, and, hers, nunavut, or, lorenz,
# Nearest to at: operatorname, in, dasyprocta, epistles, phi, of, albuquerque, agouti,
# Nearest to while: and, to, sx, badminton, circ, operatorname, phi, dasyprocta,
# Nearest to i: operatorname, saul, alchemical, lammas, nunnery, indemnity, algernon, bataan,
# Nearest to and: or, dasyprocta, with, agouti, operatorname, hbox, phi, gland,
# Nearest to often: operatorname, dddddd, basins, dasyprocta, which, gland, gt, grierson,
# Nearest to had: was, have, has, by, and, epistles, are, with,
# Nearest to when: but, and, albuquerque, with, by, in, dasyprocta, he,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to was: is, had, are, were, has, dasyprocta, operatorname, konya,
# Nearest to would: to, lens, can, only, konya, may, ivb, coke,
# Nearest to most: dasyprocta, operatorname, hbox, zar, convex, in, for, isabella,
# Nearest to by: and, with, from, dasyprocta, which, hbox, operatorname, in,
# Nearest to s: and, two, his, hbox, five, dasyprocta, of, operatorname,
# Average loss at step  42000 :  5.74729639268
# Average loss at step  44000 :  5.82267525953
# Average loss at step  46000 :  5.90966288364
# Average loss at step  48000 :  5.78954008067
# Average loss at step  50000 :  5.99566074312
# Nearest to he: it, they, which, who, that, dasyprocta, by, phi,
# Nearest to if: microscopy, that, but, which, peptidoglycan, cardiff, though, preferential,
# Nearest to can: would, may, konya, psi, nunavut, hers, difranco, is,
# Nearest to at: operatorname, in, albuquerque, epistles, phi, dasyprocta, agouti, of,
# Nearest to while: to, and, sx, difranco, badminton, circ, operatorname, hbox,
# Nearest to i: operatorname, saul, UNK, indemnity, nunnery, bataan, that, and,
# Nearest to and: or, dasyprocta, difranco, operatorname, gb, agouti, albuquerque, hbox,
# Nearest to often: which, basins, dddddd, operatorname, dasyprocta, gland, gt, it,
# Nearest to had: has, was, have, by, with, epistles, is, are,
# Nearest to when: but, and, albuquerque, that, dasyprocta, with, triglycerides, phi,
# Nearest to nine: eight, seven, zero, six, five, three, four, two,
# Nearest to was: is, had, were, has, dasyprocta, are, be, operatorname,
# Nearest to would: to, can, may, lens, difranco, could, konya, will,
# Nearest to most: dasyprocta, some, in, hbox, operatorname, all, zar, and,
# Nearest to by: with, and, from, in, operatorname, belladonna, dasyprocta, which,
# Nearest to s: two, epistles, his, hbox, dasyprocta, operatorname, six, four,
# Average loss at step  52000 :  5.8312804594
# Average loss at step  54000 :  5.69334196472
# Average loss at step  56000 :  5.81615443087
# Average loss at step  58000 :  5.32174148989
# Average loss at step  60000 :  5.60021162128
# Nearest to he: it, they, who, which, but, dasyprocta, that, when,
# Nearest to if: that, microscopy, which, but, or, preferential, peptidoglycan, cardiff,
# Nearest to can: would, may, psi, to, could, konya, from, difranco,
# Nearest to at: in, operatorname, albuquerque, from, phi, and, dasyprocta, on,
# Nearest to while: and, sx, difranco, badminton, circ, operatorname, hbox, to,
# Nearest to i: operatorname, saul, three, ii, six, nunnery, four, agouti,
# Nearest to and: or, difranco, dasyprocta, operatorname, gb, from, hbox, phi,
# Nearest to often: basins, which, dddddd, operatorname, dasyprocta, gland, trinomial, but,
# Nearest to had: has, have, was, epistles, with, were, by, is,
# Nearest to when: but, which, albuquerque, four, with, phi, six, that,
# Nearest to nine: eight, seven, four, six, five, zero, three, one,
# Nearest to was: is, were, had, dasyprocta, has, operatorname, are, biscuit,
# Nearest to would: to, can, may, could, will, difranco, lens, konya,
# Nearest to most: dasyprocta, some, operatorname, hbox, trinomial, all, and, convex,
# Nearest to by: with, from, operatorname, and, dasyprocta, in, belladonna, for,
# Nearest to s: his, two, UNK, hbox, dasyprocta, epistles, operatorname, four,
# Average loss at step  62000 :  5.66465724111
# Average loss at step  64000 :  5.45043873727
# Average loss at step  66000 :  5.42556588173
# Average loss at step  68000 :  5.34019474041
# Average loss at step  70000 :  5.54719471216
# Nearest to he: it, they, who, but, which, dasyprocta, when, by,
# Nearest to if: but, microscopy, which, that, or, though, peptidoglycan, akita,
# Nearest to can: would, may, could, psi, konya, should, to, difranco,
# Nearest to at: in, operatorname, from, albuquerque, and, on, phi, with,
# Nearest to while: and, sx, difranco, albury, circ, operatorname, to, or,
# Nearest to i: operatorname, saul, UNK, ii, six, agouti, g, dasyprocta,
# Nearest to and: or, operatorname, dasyprocta, UNK, difranco, akita, hbox, albuquerque,
# Nearest to often: which, basins, dddddd, dasyprocta, operatorname, also, they, but,
# Nearest to had: has, have, was, were, akita, epistles, with, trinomial,
# Nearest to when: but, which, albuquerque, with, operatorname, phi, dasyprocta, percussion,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to was: is, had, were, has, biscuit, toriyama, dasyprocta, operatorname,
# Nearest to would: can, may, to, will, could, difranco, akita, lens,
# Nearest to most: some, dasyprocta, operatorname, hbox, all, trinomial, gb, many,
# Nearest to by: akita, with, and, operatorname, hbox, from, dasyprocta, in,
# Nearest to s: UNK, his, akita, and, hbox, dasyprocta, epistles, four,
# Average loss at step  72000 :  5.40168757951
# Average loss at step  74000 :  5.44630539429
# Average loss at step  76000 :  5.15809926236
# Average loss at step  78000 :  4.93449510145
# Average loss at step  80000 :  5.38010610867
# Nearest to he: it, they, who, which, but, she, that, when,
# Nearest to if: but, that, microscopy, though, or, stitch, junctions, which,
# Nearest to can: would, may, could, should, to, will, konya, psi,
# Nearest to at: in, operatorname, albuquerque, dasyprocta, phi, of, from, epistles,
# Nearest to while: and, difranco, sx, circ, operatorname, albury, or, hbox,
# Nearest to i: saul, ii, operatorname, UNK, he, agouti, s, zero,
# Nearest to and: dasyprocta, or, operatorname, hbox, akita, difranco, agouti, UNK,
# Nearest to often: which, basins, dasyprocta, dddddd, they, operatorname, also, guderian,
# Nearest to had: has, have, was, were, akita, epistles, trinomial, but,
# Nearest to when: but, which, albuquerque, that, and, operatorname, zero, he,
# Nearest to nine: eight, zero, seven, six, three, five, four, one,
# Nearest to was: is, had, were, has, biscuit, konya, markov, operatorname,
# Nearest to would: can, may, to, will, could, difranco, did, konya,
# Nearest to most: some, dasyprocta, operatorname, many, all, trinomial, hbox, gb,
# Nearest to by: akita, and, operatorname, who, with, in, belladonna, which,
# Nearest to s: operatorname, four, his, two, and, dasyprocta, akita, stitch,
# Average loss at step  82000 :  5.22784584486
# Average loss at step  84000 :  5.19213095784
# Average loss at step  86000 :  5.17079389334
# Average loss at step  88000 :  5.11997405422
# Average loss at step  90000 :  5.14371181321
# Nearest to he: it, who, they, when, which, but, she, dasyprocta,
# Nearest to if: but, or, though, microscopy, then, that, stitch, which,
# Nearest to can: may, would, could, will, should, must, psi, konya,
# Nearest to at: in, operatorname, albuquerque, dasyprocta, phi, from, but, albury,
# Nearest to while: and, operatorname, difranco, but, circ, sx, hbox, or,
# Nearest to i: ii, operatorname, saul, he, yakovlev, UNK, g, when,
# Nearest to and: or, dasyprocta, operatorname, difranco, hbox, UNK, akita, but,
# Nearest to often: basins, dasyprocta, dddddd, which, operatorname, stitch, gland, guderian,
# Nearest to had: has, have, was, were, akita, with, trinomial, but,
# Nearest to when: but, which, albuquerque, and, operatorname, he, dasyprocta, stitch,
# Nearest to nine: eight, seven, six, five, four, zero, three, operatorname,
# Nearest to was: is, were, had, has, biscuit, being, markov, dasyprocta,
# Nearest to would: may, can, to, will, could, difranco, did, should,
# Nearest to most: some, dasyprocta, many, operatorname, all, more, trinomial, hbox,
# Nearest to by: with, akita, from, operatorname, belladonna, dasyprocta, hbox, and,
# Nearest to s: his, two, dasyprocta, operatorname, hbox, akita, stitch, albuquerque,
# Average loss at step  92000 :  5.13211787701
# Average loss at step  94000 :  5.08233116496
# Average loss at step  96000 :  5.21412564552
# Average loss at step  98000 :  4.96536047077
# Average loss at step  100000 :  5.00461173368
# Nearest to he: it, they, who, she, which, but, when, phi,
# Nearest to if: but, that, or, microscopy, though, then, stitch, and,
# Nearest to can: may, would, could, will, should, to, must, cannot,
# Nearest to at: in, operatorname, from, on, albuquerque, but, dasyprocta, and,
# Nearest to while: and, but, or, operatorname, difranco, roshan, circ, hbox,
# Nearest to i: ii, he, UNK, operatorname, g, yakovlev, five, four,
# Nearest to and: or, but, operatorname, dasyprocta, difranco, hbox, akita, roshan,
# Nearest to often: dasyprocta, basins, also, roshan, operatorname, dddddd, which, gland,
# Nearest to had: has, have, was, were, akita, trinomial, and, epistles,
# Nearest to when: but, and, which, albuquerque, six, after, seven, operatorname,
# Nearest to nine: eight, six, seven, three, operatorname, five, one, two,
# Nearest to was: is, were, had, has, biscuit, being, operatorname, hbox,
# Nearest to would: can, may, will, to, could, did, should, difranco,
# Nearest to most: some, many, dasyprocta, all, more, operatorname, however, trinomial,
# Nearest to by: with, belladonna, akita, and, operatorname, in, from, dasyprocta,
# Nearest to s: his, four, roshan, dasyprocta, akita, operatorname, UNK, stitch,

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')

    plt.savefig(filename)


try:
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print(
        "Please install sklearn, matplotlib, and scipy to visualize embeddings."
    )
